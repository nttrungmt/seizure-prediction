# %%
# %matplotlib inline
from matplotlib import pylab as pl
import cPickle as pickle
import pandas as pd
import numpy as np
import os

# %%
df = pd.DataFrame()
df['gb'] = pd.read_csv('../submissions/140928-predict.1.csv', index_col='clip', squeeze=True) #64
df['rf'] = pd.read_csv('../submissions/141106-predict.1.csv', index_col='clip', squeeze=True)
df['rf1'] = pd.read_csv('../submissions/140926-predict.2.csv', index_col='clip', squeeze=True)
df['dbn'] = pd.read_csv('../submissions/140930-predict.5.csv', index_col='clip', squeeze=True)
df['best'] = pd.read_csv('../submissions/141104-predict.13.csv', index_col='clip', squeeze=True)

# %%
pd.scatter_matrix(df[['gb','rf','rf1','dbn','best']],figsize=(6, 6), diagonal='kde');

# %% [markdown]
# constant from 140929-test-validate

# %%
w_gb  = 0.4
w_rf = 0.9
w_rf1 = 0.8
w_dbn = 0.6

s = w_gb + w_rf + w_rf1 + w_dbn

w_gb /= s
w_rf /= s
w_rf1 /= s
w_dbn /= s

# %%
w_gb, w_rf, w_rf1, w_dbn
# Out:
# (0.14814814814814814,
#  0.3333333333333333,
#  0.2962962962962963,
#  0.2222222222222222)

# %%
df['preictal'] = w_gb * df['gb'] + w_rf * df['rf'] + w_rf1 * df['rf1'] + w_dbn * df['dbn']

# %%
df['preictal'].to_csv('../submissions/141106-predict.2.csv', header=True)

# %%
pd.scatter_matrix(df[['best','preictal']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x117fd20d0>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117f1f390>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x114348410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x117d96590>]], dtype=object)
