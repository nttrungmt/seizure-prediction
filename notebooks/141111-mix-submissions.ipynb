# %%
# %matplotlib inline
from matplotlib import pylab as pl
import cPickle as pickle
import pandas as pd
import numpy as np
import os

# %%
df = pd.DataFrame()
df['gb'] = pd.read_csv('../submissions/140928-predict.1.csv', index_col='clip', squeeze=True) #64
df['rf'] = pd.read_csv('../submissions/141106-predict.1.csv', index_col='clip', squeeze=True)
df['rf1'] = pd.read_csv('../submissions/140926-predict.2.csv', index_col='clip', squeeze=True)
df['dbn'] = pd.read_csv('../submissions/140930-predict.5.csv', index_col='clip', squeeze=True)
df['rftime'] = pd.read_csv('../submissions/141111-predict.5.csv', index_col='clip', squeeze=True)
df['best'] = pd.read_csv('../submissions/141106-predict.3.csv', index_col='clip', squeeze=True)

# %%
pd.scatter_matrix(df,figsize=(6, 6), diagonal='kde');

# %% [markdown]
# constant from 140929-test-validate

# %%
w_gb  = 0.4
w_rf = 0.9
w_rf1 = 0.8
w_dbn = 0.6
w_rftime = 0.2

s = w_gb + w_rf + w_rf1 + w_dbn + w_rftime

w_gb /= s
w_rf /= s
w_rf1 /= s
w_dbn /= s
w_rftime /= s

# %%
w_gb, w_rf, w_rf1, w_dbn, w_rftime
# Out:
# (0.13793103448275862,
#  0.31034482758620685,
#  0.27586206896551724,
#  0.2068965517241379,
#  0.06896551724137931)

# %%
df['preictal'] = w_gb * df['gb'] + w_rf * df['rf'] + w_rf1 * df['rf1'] + w_dbn * df['dbn'] + w_rftime * df['rftime']

# %%
df['preictal'].to_csv('../submissions/141111-predict.11.csv', header=True)

# %%
pd.scatter_matrix(df[['best','preictal']])
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x11c23e850>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11c98ebd0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x11ca51410>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x11cab4410>]], dtype=object)
