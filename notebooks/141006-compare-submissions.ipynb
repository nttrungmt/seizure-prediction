# %%
# %matplotlib inline
from matplotlib import pylab as pl
import cPickle as pickle
import pandas as pd
import numpy as np
import os

# %%
df = pd.DataFrame()
df['rf1'] = pd.read_csv('../submissions/141006-predict.4.csv', index_col='clip', squeeze=True) #64
df['bestrf'] = pd.read_csv('../submissions/140926-predict.2.csv', index_col='clip', squeeze=True)
df['rf'] = pd.read_csv('../submissions/141006-predict.4.1.csv', index_col='clip', squeeze=True)
df['rf0'] = pd.read_csv('../submissions/141006-predict.4.2.csv', index_col='clip', squeeze=True)
df['best'] = pd.read_csv('../submissions/141005-predict.2.csv', index_col='clip', squeeze=True)

# %%
pd.scatter_matrix(df,figsize=(16, 16), diagonal='kde');
